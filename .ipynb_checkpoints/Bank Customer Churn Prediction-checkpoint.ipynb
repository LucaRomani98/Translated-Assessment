# %% [markdown]
# # Bank Customer Churn Prediction

# %% [markdown]
# ### Import Libraries

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import scipy 
import matplotlib.pyplot as plt
pd.options.display.float_format = '{:,.3f}'.format

# %% [markdown]
# ### Load the Data

# %%
data = pd.read_csv("data/Bank Customer Churn Prediction.csv")

# %% [markdown]
# ## 1. Exploratory Data Analysis

# %%
data.head()
# Out:
#    customer_id  credit_score country  gender  age  tenure     balance  \
# 0     15634602           619  France  Female   42       2       0.000
# 1     15647311           608   Spain  Female   41       1  83,807.860
# 2     15619304           502  France  Female   42       8 159,660.800
# 3     15701354           699  France  Female   39       1       0.000
# 4     15737888           850   Spain  Female   43       2 125,510.820
#
#    products_number  credit_card  active_member  estimated_salary  churn
# 0                1            1              1       101,348.880      1
# 1                1            0              1       112,542.580      0
# 2                3            1              0       113,931.570      1
# 3                2            0              0        93,826.630      0
# 4                1            1              1        79,084.100      0

# %%
print("The number of samples is",len(data))
print("The number of features for each sample is", len(data.columns))
# Out:
# The number of samples is 10000
# The number of features for each sample is 12

# %% [markdown]
# Let's check if we have some null value:

# %%
data.isnull().sum()
# Out:
# customer_id         0
# credit_score        0
# country             0
# gender              0
# age                 0
# tenure              0
# balance             0
# products_number     0
# credit_card         0
# active_member       0
# estimated_salary    0
# churn               0
# dtype: int64

# %% [markdown]
# As we can see we don't have any missing value.

# %%
cor = data.corr()[["churn"]]
cor.churn = abs(cor.churn)
cor.churn.sort_values(ascending = False)[1:]
# Out:
# age                0.285
# active_member      0.156
# balance            0.119
# products_number    0.048
# credit_score       0.027
# tenure             0.014
# estimated_salary   0.012
# credit_card        0.007
# customer_id        0.006
# Name: churn, dtype: float64

# %%
data['churn'].value_counts()
# Out:
# 0    7963
# 1    2037
# Name: churn, dtype: int64

# %% [markdown]
# As we can see the Churn column is highly unbalanced, since only 20% of the samples result in a positive value; we'll need to take this fact into account when training our model.

# %%
#split the dataset
data0 = data[data.churn == 0]
data1 = data[data.churn == 1]

# %%
pvalue = scipy.stats.ks_2samp(data0.age, data1.age, alternative='two-sided', mode='auto').pvalue
print(f"The p-value for the ks_2samp test is: {pvalue}")
# Out:
# The p-value for the ks_2samp test is: 2.11904599621996e-217

# %%
plt.figure(figsize=(20,6))
sns.histplot(x=data["age"],hue=data["churn"])
plt.title("Age Distribution")
plt.show()

# %%
pvalue = scipy.stats.ks_2samp(data0.balance, data1.balance, alternative='two-sided', mode='auto').pvalue
print(f"The p-value for the ks_2samp test is: {pvalue}")
# Out:
# The p-value for the ks_2samp test is: 4.4608718125128645e-32

# %%
plt.figure(figsize=(20,6))
sns.histplot(x=data["balance"],hue=data["churn"])
plt.title("Bank Balance Distribution")
plt.show()

# %%
pvalue = scipy.stats.ks_2samp(data0.credit_score, data1.credit_score, alternative='two-sided', mode='auto').pvalue
print(f"The p-value for the ks_2samp test is: {pvalue}")
# Out:
# The p-value for the ks_2samp test is: 0.030059908312210937

# %%
plt.figure(figsize=(20,6))
sns.histplot(x=data["credit_score"],hue=data["churn"])
plt.title("Credit Score Distribution")
plt.show()

# %%
pvalue = scipy.stats.ks_2samp(data0.country, data1.country, alternative='two-sided', mode='auto').pvalue
print(f"The p-value for the ks_2samp test is: {pvalue}")
# Out:
# The p-value for the ks_2samp test is: 1.832977984948256e-24

# %%
plt.figure(figsize=(20,6))
sns.histplot(x=data["country"],hue=data["churn"])
plt.title("Credit Score Distribution")
plt.show()

# %%
pvalue = scipy.stats.ks_2samp(data0.credit_card, data1.credit_card, alternative='two-sided', mode='auto').pvalue
print(f"The p-value for the ks_2samp test is: {pvalue}")
# Out:
# The p-value for the ks_2samp test is: 0.9999078274538944

# %%
plt.figure(figsize=(20,6))
sns.histplot(x=data["credit_card"],hue=data["churn"])
plt.title("Credit Score Distribution")
plt.show()

# %%
pvalue = scipy.stats.ks_2samp(data0.credit_card, data1.credit_card, alternative='two-sided', mode='auto').pvalue
print(f"The p-value for the ks_2samp test is: {pvalue}")
# Out:
# The p-value for the ks_2samp test is: 0.9999078274538944

# %%
pvalue = scipy.stats.ks_2samp(data0.tenure, data1.tenure, alternative='two-sided', mode='auto').pvalue
print(f"The p-value for the ks_2samp test is: {pvalue}")
# Out:
# The p-value for the ks_2samp test is: 0.5434473654076404

# %%
plt.figure(figsize=(20,6))
sns.histplot(x=data["tenure"],hue=data["churn"])
plt.title("Credit Score Distribution")
plt.show()

# %%
pvalue = scipy.stats.ks_2samp(data0.products_number, data1.products_number, alternative='two-sided', mode='auto').pvalue
print(f"The p-value for the ks_2samp test is: {pvalue}")
# Out:
# The p-value for the ks_2samp test is: 6.577936228403955e-76

# %%
plt.figure(figsize=(20,6))
sns.histplot(x=data["products_number"],hue=data["churn"])
plt.title("Credit Score Distribution")
plt.show()
