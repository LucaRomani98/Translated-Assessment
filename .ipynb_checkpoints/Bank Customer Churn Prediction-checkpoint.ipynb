# %% [markdown]
# # Bank Customer Churn Prediction

# %% [markdown]
# ### Import Libraries

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import scipy 
import matplotlib.pyplot as plt
pd.options.display.float_format = '{:,.2f}'.format

# %% [markdown]
# ### Load the Data

# %% [markdown]
# First let's load the data. I'm going to use the Pandas library since the dataset is in a .csv format.

# %%
data = pd.read_csv("data/Bank Customer Churn Prediction.csv")

# %% [markdown]
# ## 1. Exploratory Data Analysis

# %% [markdown]
# Let's print the first rows to see how the data is organized:

# %%
data.head()
# Out:
#    customer_id  credit_score country  gender  age  tenure    balance  \
# 0     15634602           619  France  Female   42       2       0.00
# 1     15647311           608   Spain  Female   41       1  83,807.86
# 2     15619304           502  France  Female   42       8 159,660.80
# 3     15701354           699  France  Female   39       1       0.00
# 4     15737888           850   Spain  Female   43       2 125,510.82
#
#    products_number  credit_card  active_member  estimated_salary  churn
# 0                1            1              1        101,348.88      1
# 1                1            0              1        112,542.58      0
# 2                3            1              0        113,931.57      1
# 3                2            0              0         93,826.63      0
# 4                1            1              1         79,084.10      0

# %%
print("The number of samples is",len(data))
print("The number of features for each sample is", len(data.columns))
# Out:
# The number of samples is 10000
# The number of features for each sample is 12

# %% [markdown]
# The dataset contains 10000 samples, each having 12 features.
# The features are:
#  1.  **churn**: indicates if a customer stops doing business with the bank. Is the variable we will try to classify with a Machine Learning Model;
#  2. **customer_id**: unique identifier of the customer;
#  3. **credit_score**: score which measures the creditworthiness of the customer;
#  4. **country**: country of residence of the customer;
#  5. **gender**: sex of the customer;
#  6. **age**: age of the customer;
#  7. **tenure**: indicates how many years a customer has been associated with the bank;
#  8. **balance**: amount of money present in the bank account;
#  9. **products_number**: number of products from that bank;
#  10. **credit_card**: indicates if a customer owns a credit card from that bank;
#  11. **active_member**: indicates if a customer is an active member of that bank;
#  12. **estimated_salary**: total income of the customer.

# %% [markdown]
# Let's check if we have some null value:

# %%
data.isnull().sum()
# Out:
# customer_id         0
# credit_score        0
# country             0
# gender              0
# age                 0
# tenure              0
# balance             0
# products_number     0
# credit_card         0
# active_member       0
# estimated_salary    0
# churn               0
# dtype: int64

# %% [markdown]
# As we can see we don't have any missing value.
# Let's drop the **customer_id** column, since it's not useful for our analysis:

# %%
data.drop(labels = ['customer_id'], inplace = True, axis = 1)
data
# Out:
#       credit_score  country  gender  age  tenure    balance  products_number  \
# 0              619   France  Female   42       2       0.00                1
# 1              608    Spain  Female   41       1  83,807.86                1
# 2              502   France  Female   42       8 159,660.80                3
# 3              699   France  Female   39       1       0.00                2
# 4              850    Spain  Female   43       2 125,510.82                1
# ...            ...      ...     ...  ...     ...        ...              ...
# 9995           771   France    Male   39       5       0.00                2
# 9996           516   France    Male   35      10  57,369.61                1
# 9997           709   France  Female   36       7       0.00                1
# 9998           772  Germany    Male   42       3  75,075.31                2
# 9999           792   France  Female   28       4 130,142.79                1
#
#       credit_card  active_member  estimated_salary  churn
# 0               1              1        101,348.88      1
# 1               0              1        112,542.58      0
# 2               1              0        113,931.57      1
# 3               0              0         93,826.63      0
# 4               1              1         79,084.10      0
# ...           ...            ...               ...    ...
# 9995            1              0         96,270.64      0
# 9996            1              1        101,699.77      0
# 9997            0              1         42,085.58      1
# 9998            1              0         92,888.52      1
# 9999            1              0         38,190.78      0
#
# [10000 rows x 11 columns]

# %% [markdown]
# Let's now plot the distribution of each feature to see if there is something important to notice:

# %%
columns_list = ['country', 'age', 'gender', 'balance', 'credit_score', 'tenure',
                   'estimated_salary', 'products_number', 'credit_card', 'active_member']

# specify histogram parameters
colors = ['red', 'green', 'yellow', 'blue', 'orange', 'purple', 'cyan', 'magenta', 'lime', 'pink']
alpha = 0.5
histtype = 'bar'

# create subplots
fig, axs = plt.subplots(len(columns_list), figsize = (12, 63))

# plot each column on a separate subplot
for i, column in enumerate(columns_list):
    axs[i].hist(data[column], color=colors[i], alpha=alpha, rwidth = 0.9, histtype=histtype)
    axs[i].set_title('Histogram of {}'.format(column))
    axs[i].set_xlabel(column)
    axs[i].set_ylabel('Number of Samples')

# adjust the spacing between subplots
fig.tight_layout()

# display the plot
plt.show()

# %% [markdown]
# **Important things to notice**:
#
# * We can see that many entries of the **balance** column are zero. These can be seen as missing data, but I'm going to assume for the rest of the analysis that these are regular data, since it's not unusual to have an empty bank account;
# * The **estimated_salary** seems to follow a Uniform Distribution between 0 and 200,000;
# * The **country** column only takes three value, *Spain*, *Germany* and *France*, with the latter appearing in 50% of the samples;
#
# Now let's see the distribution of the target variable.

# %%
data['churn'].value_counts().plot(kind = 'pie', autopct='%1.1f%%')
# Out:
# <AxesSubplot:ylabel='churn'>

# %% [markdown]
# As we can see the Churn column is highly unbalanced, since only 20% of the samples result in a positive value; we'll need to take this fact into account when training our model.
# Now let's see how the distribution of the variables changes if we take only positive samples or only negative samples:

# %%
#split the dataset
data0 = data[data.churn == 0]
data1 = data[data.churn == 1]

fig, axs = plt.subplots(len(columns_list), figsize = (12, 63))
for i, column in enumerate(columns_list):
    '''since the churn column isn't balanced, I'm going to set the density parameter as True, so that the area under
    the two histograms are the same, and the differences in the distributions are clearer'''
    axs[i].hist(data0[column], color='cyan', alpha=alpha, rwidth = 0.9, histtype=histtype, label = 'Churn = 0', density = True)
    axs[i].hist(data1[column], color='red', alpha=alpha, rwidth = 0.9, histtype=histtype, label = 'Churn = 1', density = True)
    axs[i].set_xlabel(column)
    axs[i].set_ylabel('Density')
    axs[i].set_title(f'{column} distributions')
    axs[i].legend(loc='upper right')

# display the plot
plt.show()

# %% [markdown]
# From the graph we can see that older people tend to churn more than young people. We can also see that the majority of people who churned only has 1 product from the bank.
# Let's also run some statistical tests to compare the distributions of the features in the two cases. I'm going to use the Kolmogorov-Smirnov test, and check for its p-value (a low p-value indicates that the two distributions are probably different):

# %%
for column in columns_list:
    pvalue = scipy.stats.ks_2samp(data0[column], data1[column], alternative='two-sided', mode='auto').pvalue
    print(f"The p-value calculated by the ks_2samp test for the {column} column is: {pvalue}")
# Out:
# The p-value calculated by the ks_2samp test for the country column is: 1.832977984948256e-24
# The p-value calculated by the ks_2samp test for the age column is: 2.11904599621996e-217
# The p-value calculated by the ks_2samp test for the gender column is: 5.637875793266966e-25
# The p-value calculated by the ks_2samp test for the balance column is: 4.4608718125128645e-32
# The p-value calculated by the ks_2samp test for the credit_score column is: 0.030059908312210937
# The p-value calculated by the ks_2samp test for the tenure column is: 0.5434473654076404
# The p-value calculated by the ks_2samp test for the estimated_salary column is: 0.32498799277316914
# The p-value calculated by the ks_2samp test for the products_number column is: 6.577936228403955e-76
# The p-value calculated by the ks_2samp test for the credit_card column is: 0.9999078274538944
# The p-value calculated by the ks_2samp test for the active_member column is: 9.575035207546793e-54

# %% [markdown]
# For most of the features the p-value is very close to zero, meaning their distribution changes if a customer churns or not.
# For **credit_score** the p-value is low, but not as low as many other features, with it being 0.03.
# For **tenure**, **estimated_salary** and **credit_card** the p-value was high so we can't say that the two distributions are different.

# %% [markdown]
# ## 2. Modeling

# %% [markdown]
# Let's now build some classification models to predict if a customer churns or not.
# First let's split the dataset into a training set and a testing set, while also normalizing the columns using *Sklearn* **MinMaxScaler** and **LabelEncoder** for the categorical columns *country* and *gender*.

# %%
#import other useful libraries
from sklearn.model_selection import train_test_split, cross_val_score, LeaveOneOut
from sklearn.metrics import accuracy_score,  f1_score, recall_score
from sklearn.model_selection import GridSearchCV
from sklearn.preprocessing import MinMaxScaler,LabelEncoder

# %%
#Separate features and target columns
X = data.drop('churn', axis = 1)
y = data['churn']

#encode the labels
X['country'] = LabelEncoder().fit_transform(X['country'])
X['gender'] = LabelEncoder().fit_transform(X['gender'])

#split into train and test
X_train, X_test, y_train, y_test = train_test_split(X,y, test_size = 0.2, stratify = y)

#normalize the data
scaler = MinMaxScaler()
X_train = scaler.fit_transform(X_train)
X_test = scaler.transform(X_test)

# %% [markdown]
# Now to the models. Since we have an high class imbalance I'm going to use the **F1 Score** and **Recall** as the main metrics, to keep track of which model performs the best.

# %% [markdown]
# #### Logistic Regression

# %%
from sklearn.linear_model import LogisticRegression

# %%
logreg = LogisticRegression(solver = 'liblinear')

logreg.fit(X_train, y_train)

log_pred = logreg.predict(X_test)

log_acc = accuracy_score(log_pred, y_test)
log_f1 = f1_score(log_pred, y_test)
log_rec = recall_score(log_pred, y_test)

print(f"The Accuracy on Test set for the Logistic Regression Model is: {log_acc}")
print(f"The F1 Score on Test set for the Logistic Regression Model is: {log_f1}")
print(f"The Recall Score on Test set for the Logistic Regression Model is: {log_rec}")
# Out:
# The Accuracy on Test set for the Logistic Regression Model is: 0.8045
# The F1 Score on Test set for the Logistic Regression Model is: 0.2407766990291262
# The Recall Score on Test set for the Logistic Regression Model is: 0.5740740740740741

# %% [markdown]
# #### Random Forest Classifier

# %%
from sklearn.ensemble import RandomForestClassifier

# %%
rfc = RandomForestClassifier()

rfc.fit(X_train, y_train)

rfc_pred = rfc.predict(X_test)

rfc_acc = accuracy_score(rfc_pred, y_test)
rfc_f1 = f1_score(rfc_pred, y_test)
rfc_rec = recall_score(rfc_pred, y_test)

print(f"The Accuracy on Test set for the Random Forest Classifier Model is: {rfc_acc}")
print(f"The F1 Score on Test set for the Random Forest Classifier Model is: {rfc_f1}")
print(f"The Recall Score on Test set for the Random Forest Classifier Model is: {rfc_rec}")
# Out:
# The Accuracy on Test set for the Random Forest Classifier Model is: 0.863
# The F1 Score on Test set for the Random Forest Classifier Model is: 0.5608974358974359
# The Recall Score on Test set for the Random Forest Classifier Model is: 0.8064516129032258

# %% [markdown]
# #### Multinomial Naive Bayes

# %%
from sklearn.naive_bayes import MultinomialNB

# %%
mnb = MultinomialNB()

mnb.fit(X_train, y_train)

mnb_pred= mnb.predict(X_test)

mnb_acc = accuracy_score(mnb_pred, y_test)
mnb_f1 = f1_score(mnb_pred, y_test)
mnb_rec = recall_score(mnb_pred, y_test)


print(f"The Accuracy on Test set for the Multinomial Naive Bayes Model is: {mnb_acc}")
print(f"The F1 Score on Test set for the Multinomial Naive Bayes Model is: {mnb_f1}")
print(f"The Recall Score on Test set for the Multinomial Naive Bayes Model is: {mnb_rec}")
# Out:
# The Accuracy on Test set for the Multinomial Naive Bayes Model is: 0.7965
# The F1 Score on Test set for the Multinomial Naive Bayes Model is: 0.0
# The Recall Score on Test set for the Multinomial Naive Bayes Model is: 0.0
# C:\Users\Luca Romani\anaconda3\lib\site-packages\sklearn\metrics\_classification.py:1318: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 due to no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))

# %% [markdown]
# #### Gaussian Naive Bayes

# %%
from sklearn.naive_bayes import GaussianNB

# %%
gnb = GaussianNB()

gnb.fit(X_train, y_train)

gnb_pred = mnb.predict(X_test)

gnb_acc = accuracy_score(gnb_pred, y_test)
gnb_f1 = f1_score(gnb_pred, y_test)
gnb_rec = recall_score(gnb_pred, y_test)

print(f"The Accuracy on Test set for the Gaussian Naive Bayes Model is: {gnb_acc}")
print(f"The F1 Score on Test set for the Gaussian Naive Bayes Model is: {gnb_f1}")
print(f"The Recall Score on Test set for the Gaussian Naive Bayes Model is: {gnb_rec}")
# Out:
# The Accuracy on Test set for the Gaussian Naive Bayes Model is: 0.7965
# The F1 Score on Test set for the Gaussian Naive Bayes Model is: 0.0
# The Recall Score on Test set for the Gaussian Naive Bayes Model is: 0.0
# C:\Users\Luca Romani\anaconda3\lib\site-packages\sklearn\metrics\_classification.py:1318: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 due to no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))

# %% [markdown]
# #### SVC

# %%
from sklearn.svm import SVC

# %%
svc = SVC()

svc.fit(X_train, y_train)

svc_pred = svc.predict(X_test) 

svc_acc = accuracy_score(svc_pred, y_test)
svc_f1 = f1_score(svc_pred, y_test)
svc_rec = recall_score(svc_pred, y_test)

print(f"The Accuracy on Test set for the SVC Model is: {svc_acc}")
print(f"The F1 Score on Test set for the SVC Model is: {svc_f1}")
print(f"The Recall Score on Test set for the SVC Model is: {svc_rec}")
# Out:
# The Accuracy on Test set for the SVC Model is: 0.848
# The F1 Score on Test set for the SVC Model is: 0.45126353790613716
# The Recall Score on Test set for the SVC Model is: 0.8503401360544217

# %% [markdown]
# First thing to notice is that both the Gaussian and the Multinomial Naive Bayes resulted in a Recall of 0. This means that these model predictions are constant and equal to 0, obtaining an accuracy of 80% anyway, due to the class imbalance. This can probably be solved by performing an Undersampling or Upsampling on the dataset. The best models were the Random Forest Classifier and SVC, with the first one obtaining the highest F1 Score of 0.58 and the latter obtaining the highest Recall Score of 0.82, both having an Accuracy on the Test Set of roughly 85%.
#
# #### Neural Network Approach
#
#
# Let's now try building a simple Neural Network Architecture to see how it performs on this dataset:

# %%
#import libraries
import tensorflow as tf
from tensorflow.keras import callbacks

# %%
#taking first 2000 samples of train set as a validation set, to keep track of neural network performance during training

X_val = X_train[:2000]
y_val = y_train[:2000]
X_train = X_train[2000:]
y_train = y_train[2000:]

# %% [markdown]
# The Model is a sequence of 2 Fully Connected Blocks, with a ReLU activation in between, and a final Fully Connected block with a Sigmoid activation to calculate the final score. As the loss I'm going to use the **Binary Crossentropy**, and **Adam** as the optimizer; I also added **Callbacks** that keep track of the Validation Loss with a Patience of 5, and the option *restore_best_weights* activated, to avoid Overfitting.

# %%
model = tf.keras.Sequential([
    tf.keras.layers.Dense(128, activation = 'relu'),
    tf.keras.layers.Dense(64, activation = 'relu'),
    tf.keras.layers.Dense(1, activation = 'sigmoid')
])


model.compile(optimizer='adam',
              loss=tf.keras.losses.BinaryCrossentropy(from_logits=False),
               metrics=['accuracy'])


cbs = [
    callbacks.TerminateOnNaN(),
    callbacks.EarlyStopping(monitor='val_loss', patience=5, 
                            restore_best_weights=True, verbose=1)   
]

# %%
#train the model
history = model.fit(X_train, y_train, epochs = 200, validation_data = (X_val, y_val), callbacks = cbs)
# Out:
# Epoch 1/200
# 188/188 [==============================] - 1s 2ms/step - loss: 0.4841 - accuracy: 0.7972 - val_loss: 0.4603 - val_accuracy: 0.7960
# Epoch 2/200
# 188/188 [==============================] - 0s 1ms/step - loss: 0.4392 - accuracy: 0.8107 - val_loss: 0.4330 - val_accuracy: 0.8160
# Epoch 3/200
# 188/188 [==============================] - 0s 1ms/step - loss: 0.4124 - accuracy: 0.8288 - val_loss: 0.4177 - val_accuracy: 0.8180
# Epoch 4/200
# 188/188 [==============================] - 0s 1ms/step - loss: 0.3812 - accuracy: 0.8423 - val_loss: 0.3905 - val_accuracy: 0.8400
# Epoch 5/200
# 188/188 [==============================] - 0s 1ms/step - loss: 0.3677 - accuracy: 0.8477 - val_loss: 0.3858 - val_accuracy: 0.8435
# Epoch 6/200
# 188/188 [==============================] - 0s 1ms/step - loss: 0.3608 - accuracy: 0.8495 - val_loss: 0.3696 - val_accuracy: 0.8510
# Epoch 7/200
# 188/188 [==============================] - 0s 1ms/step - loss: 0.3569 - accuracy: 0.8558 - val_loss: 0.3822 - val_accuracy: 0.8490
# Epoch 8/200
# 188/188 [==============================] - 0s 1ms/step - loss: 0.3512 - accuracy: 0.8560 - val_loss: 0.3709 - val_accuracy: 0.8445
# Epoch 9/200
# 188/188 [==============================] - 0s 1ms/step - loss: 0.3499 - accuracy: 0.8557 - val_loss: 0.3724 - val_accuracy: 0.8530
# Epoch 10/200
# 188/188 [==============================] - 0s 1ms/step - loss: 0.3460 - accuracy: 0.8547 - val_loss: 0.3686 - val_accuracy: 0.8535
# Epoch 11/200
# 188/188 [==============================] - 0s 1ms/step - loss: 0.3458 - accuracy: 0.8572 - val_loss: 0.3639 - val_accuracy: 0.8525
# Epoch 12/200
# 188/188 [==============================] - 0s 1ms/step - loss: 0.3436 - accuracy: 0.8565 - val_loss: 0.3612 - val_accuracy: 0.8560
# Epoch 13/200
# 188/188 [==============================] - 0s 1ms/step - loss: 0.3421 - accuracy: 0.8570 - val_loss: 0.3735 - val_accuracy: 0.8510
# Epoch 14/200
# 188/188 [==============================] - 0s 1ms/step - loss: 0.3394 - accuracy: 0.8593 - val_loss: 0.3618 - val_accuracy: 0.8605
# Epoch 15/200
# 188/188 [==============================] - 0s 1ms/step - loss: 0.3380 - accuracy: 0.8597 - val_loss: 0.3682 - val_accuracy: 0.8545
# Epoch 16/200
# 188/188 [==============================] - 0s 1ms/step - loss: 0.3357 - accuracy: 0.8603 - val_loss: 0.3596 - val_accuracy: 0.8570
# Epoch 17/200
# 188/188 [==============================] - 0s 1ms/step - loss: 0.3332 - accuracy: 0.8638 - val_loss: 0.3645 - val_accuracy: 0.8525
# Epoch 18/200
# 188/188 [==============================] - 0s 1ms/step - loss: 0.3310 - accuracy: 0.8643 - val_loss: 0.3589 - val_accuracy: 0.8565
# Epoch 19/200
# 188/188 [==============================] - 0s 1ms/step - loss: 0.3307 - accuracy: 0.8615 - val_loss: 0.3599 - val_accuracy: 0.8545
# Epoch 20/200
# 188/188 [==============================] - 0s 1ms/step - loss: 0.3312 - accuracy: 0.8622 - val_loss: 0.3575 - val_accuracy: 0.8560
# Epoch 21/200
# 188/188 [==============================] - 0s 1ms/step - loss: 0.3281 - accuracy: 0.8648 - val_loss: 0.3616 - val_accuracy: 0.8515
# Epoch 22/200
# 188/188 [==============================] - 0s 1ms/step - loss: 0.3265 - accuracy: 0.8673 - val_loss: 0.3569 - val_accuracy: 0.8575
# Epoch 23/200
# 188/188 [==============================] - 0s 1ms/step - loss: 0.3261 - accuracy: 0.8652 - val_loss: 0.3645 - val_accuracy: 0.8555
# Epoch 24/200
# 188/188 [==============================] - 0s 1ms/step - loss: 0.3247 - accuracy: 0.8665 - val_loss: 0.3797 - val_accuracy: 0.8540
# Epoch 25/200
# 188/188 [==============================] - 0s 1ms/step - loss: 0.3232 - accuracy: 0.8655 - val_loss: 0.3581 - val_accuracy: 0.8560
# Epoch 26/200
# 188/188 [==============================] - 0s 1ms/step - loss: 0.3247 - accuracy: 0.8650 - val_loss: 0.3615 - val_accuracy: 0.8460
# Epoch 27/200
# 158/188 [========================>.....] - ETA: 0s - loss: 0.3260 - accuracy: 0.8647Restoring model weights from the end of the best epoch: 22.
# 188/188 [==============================] - 0s 1ms/step - loss: 0.3202 - accuracy: 0.8672 - val_loss: 0.3684 - val_accuracy: 0.8555
# Epoch 27: early stopping

# %%
plt.figure(figsize=(10,7))
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('Total Loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend(['Train', 'Validation'], loc='lower right')
plt.show()

# %%
plt.figure(figsize=(10,7))
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.title('Total Loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend(['Train', 'Validation'], loc='lower right')
plt.show()

# %%
nn_pred = model.predict(X_test).round()

nn_acc = accuracy_score(y_test, nn_pred)
nn_f1 = f1_score(y_test, nn_pred)
nn_rec = recall_score(y_test, nn_pred)

print(nn_f1)
print(nn_acc)
print(nn_rec)
# Out:
# 63/63 [==============================] - 0s 581us/step
# 0.5552147239263804
# 0.855
# 0.44471744471744473

# %%
# Out:
# 245.0
